# %% [markdown]
# # Chatbot notebook - Kernel instructions
#
# This notebook expects to run with the `chatbot` virtual environment. If you see ImportError or the notebook behaves oddly, select the kernel named **Python (chatbot_env)**.
#
# To add the kernel (already installed for you), open the kernel picker in VS Code or Jupyter and choose **Python (chatbot_env)**. If it doesn't appear immediately, restart VS Code.

# %%
# Kernel check for chatbot virtualenv
import sys, os
expected = r'C:/Users/deepu/OneDrive/Desktop/Data Science, ML, DL & MLops Projects/AI Models/Langgraph/agentic Workflows/chatbot/Scripts/python.exe'
print('Notebook python executable:', sys.executable)
print('Expected virtualenv executable:', expected)
if os.path.normcase(os.path.abspath(sys.executable)) != os.path.normcase(os.path.abspath(expected)):
    print('\nWARNING: Kernel mismatch detected. Select the kernel 
 and re-run this cell.')
else:
    print('\nKernel matches the project virtualenv. You should be good to run imports.')

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated, Literal
from langchain_core.messages import BaseMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
